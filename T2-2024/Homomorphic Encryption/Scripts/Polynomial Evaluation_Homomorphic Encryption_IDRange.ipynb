# %%
import numpy as np
import tenseal as ts
from sympy import Symbol, expand

def create_single_term_polynomial(suspicious_value):
    x = Symbol('x')
    polynomial = (x - suspicious_value)
    print(f"Generated Polynomial: {polynomial}")  # Debug: print the polynomial
    return expand(polynomial)

def evaluate_polynomial(polynomial, value):
    return polynomial.evalf(subs={Symbol('x'): value})

def homomorphic_search_linear(suspicious_list, shared_list):
    # Initialize TenSEAL context with higher scale for better precision
    context = ts.context(ts.SCHEME_TYPE.CKKS, 8192, 7)
    scale = 2 ** 40

    matches = []

    # Encrypt and compare each shared value to each suspicious value individually
    for shared in shared_list:
        encrypted_shared = ts.ckks_vector(context, [shared], scale)

        for suspicious_value in suspicious_list:
            polynomial = create_single_term_polynomial(suspicious_value)

            result = ts.ckks_vector(context, [0], scale)

            # Evaluate the single-term polynomial (linear) at the encrypted value
            for i, coef in enumerate(polynomial.as_coefficients_dict().values()):
                encrypted_coef = ts.ckks_vector(context, [coef], scale)
                term = encrypted_shared ** i * encrypted_coef
                result += term

            decrypted_result = result.decrypt()[0]

            # Print results for debugging
            direct_result = evaluate_polynomial(polynomial, shared)
            print(f"Evaluating for {shared} with {suspicious_value}: Decrypted Result = {decrypted_result}, Direct Result = {direct_result}")

            # Check if the polynomial evaluates close to zero
            if abs(decrypted_result) < 1e-5:
                matches.append(shared)
                break  # Stop checking once a match is found

    return matches

# Example usage
suspicious_list = np.random.randint(1000000, 9999999, size=5).tolist()  # Reduced list size
shared_list = np.random.randint(1000000, 9999999, size=10).tolist()      # Reduced list size

# Hardcode a common value in both lists
common_value = 1234
suspicious_list.append(common_value)
shared_list.append(common_value)

print(f"Suspicious list: {suspicious_list}")
print(f"Shared list: {shared_list}")

# Call the function with homomorphic encryption and linear validation
matches = homomorphic_search_linear(suspicious_list, shared_list)

# Display matches
print(f"Suspicious people found: {matches}")
# Out:
# Suspicious list: [8638440, 3579113, 5506064, 5561835, 6584737, 1234]
# Shared list: [8466349, 5821212, 1672229, 8339999, 8568770, 8508476, 3321456, 8792272, 4718199, 3119089, 1234]
# Generated Polynomial: x - 8638440
# Evaluating for 8466349 with 8638440: Decrypted Result = -10755.687960047719, Direct Result = -172091.000000000
# Generated Polynomial: x - 3579113
# Evaluating for 8466349 with 3579113: Decrypted Result = 305452.26100596244, Direct Result = 4887236.00000000
# Generated Polynomial: x - 5506064
# Evaluating for 8466349 with 5506064: Decrypted Result = 185017.81864632192, Direct Result = 2960285.00000000
# Generated Polynomial: x - 5561835
# Evaluating for 8466349 with 5561835: Decrypted Result = 181532.1310531317, Direct Result = 2904514.00000000
# Generated Polynomial: x - 6584737
# Evaluating for 8466349 with 6584737: Decrypted Result = 117600.75401863229, Direct Result = 1881612.00000000
# Generated Polynomial: x - 1234
# Evaluating for 8466349 with 1234: Decrypted Result = 529069.7064555092, Direct Result = 8465115.00000000
# Generated Polynomial: x - 8638440
# Evaluating for 5821212 with 8638440: Decrypted Result = -176076.75592628279, Direct Result = -2817228.00000000
# Generated Polynomial: x - 3579113
# Evaluating for 5821212 with 3579113: Decrypted Result = 140131.19198969158, Direct Result = 2242099.00000000
# Generated Polynomial: x - 5506064
# Evaluating for 5821212 with 5506064: Decrypted Result = 19696.750414437294, Direct Result = 315148.000000000
# Generated Polynomial: x - 5561835
# Evaluating for 5821212 with 5561835: Decrypted Result = 16211.063220870836, Direct Result = 259377.000000000
# Generated Polynomial: x - 6584737
# Evaluating for 5821212 with 6584737: Decrypted Result = -47720.3137666854, Direct Result = -763525.000000000
# Generated Polynomial: x - 1234
# Evaluating for 5821212 with 1234: Decrypted Result = 363748.63747627876, Direct Result = 5819978.00000000
# Generated Polynomial: x - 8638440
# Evaluating for 1672229 with 8638440: Decrypted Result = -435388.20293310896, Direct Result = -6966211.00000000
# Generated Polynomial: x - 3579113
# Evaluating for 1672229 with 3579113: Decrypted Result = -119180.25412831732, Direct Result = -1906884.00000000
# Generated Polynomial: x - 5506064
# Evaluating for 1672229 with 5506064: Decrypted Result = -239614.69577988892, Direct Result = -3833835.00000000
# Generated Polynomial: x - 5561835
# Evaluating for 1672229 with 5561835: Decrypted Result = -243100.38331817253, Direct Result = -3889606.00000000
# Generated Polynomial: x - 6584737
# Evaluating for 1672229 with 6584737: Decrypted Result = -307031.76014159503, Direct Result = -4912508.00000000
# Generated Polynomial: x - 1234
# Evaluating for 1672229 with 1234: Decrypted Result = 104437.19109128503, Direct Result = 1670995.00000000
# Generated Polynomial: x - 8638440
# Evaluating for 8339999 with 8638440: Decrypted Result = -18652.56275669931, Direct Result = -298441.000000000
# Generated Polynomial: x - 3579113
# Evaluating for 8339999 with 3579113: Decrypted Result = 297555.3850359311, Direct Result = 4760886.00000000
# Generated Polynomial: x - 5506064
# Evaluating for 8339999 with 5506064: Decrypted Result = 177120.943544721, Direct Result = 2833935.00000000
# Generated Polynomial: x - 5561835
# Evaluating for 8339999 with 5561835: Decrypted Result = 173635.25525589872, Direct Result = 2778164.00000000
# Generated Polynomial: x - 6584737
# Evaluating for 8339999 with 6584737: Decrypted Result = 109703.87864943357, Direct Result = 1755262.00000000
# Generated Polynomial: x - 1234
# Evaluating for 8339999 with 1234: Decrypted Result = 521172.83081946475, Direct Result = 8338765.00000000
# Generated Polynomial: x - 8638440
# Evaluating for 8568770 with 8638440: Decrypted Result = -4354.375164004537, Direct Result = -69670.0000000000
# Generated Polynomial: x - 3579113
# Evaluating for 8568770 with 3579113: Decrypted Result = 311853.5729021739, Direct Result = 4989657.00000000
# Generated Polynomial: x - 5506064
# Evaluating for 8568770 with 5506064: Decrypted Result = 191419.13206291612, Direct Result = 3062706.00000000
# Generated Polynomial: x - 5561835
# Evaluating for 8568770 with 5561835: Decrypted Result = 187933.44398535392, Direct Result = 3006935.00000000
# Generated Polynomial: x - 6584737
# Evaluating for 8568770 with 6584737: Decrypted Result = 124002.06683619662, Direct Result = 1984033.00000000
# Generated Polynomial: x - 1234
# Evaluating for 8568770 with 1234: Decrypted Result = 535471.018365877, Direct Result = 8567536.00000000
# Generated Polynomial: x - 8638440
# Evaluating for 8508476 with 8638440: Decrypted Result = -8122.749738464098, Direct Result = -129964.000000000
# Generated Polynomial: x - 3579113
# Evaluating for 8508476 with 3579113: Decrypted Result = 308085.198113499, Direct Result = 4929363.00000000
# Generated Polynomial: x - 5506064
# Evaluating for 8508476 with 5506064: Decrypted Result = 187650.75598781445, Direct Result = 3002412.00000000
# Generated Polynomial: x - 5561835
# Evaluating for 8508476 with 5561835: Decrypted Result = 184165.0687898751, Direct Result = 2946641.00000000
# Generated Polynomial: x - 6584737
# Evaluating for 8508476 with 6584737: Decrypted Result = 120233.69139276947, Direct Result = 1923739.00000000
# Generated Polynomial: x - 1234
# Evaluating for 8508476 with 1234: Decrypted Result = 531702.642929938, Direct Result = 8507242.00000000
# Generated Polynomial: x - 8638440
# Evaluating for 3321456 with 8638440: Decrypted Result = -332311.5120530696, Direct Result = -5316984.00000000
# Generated Polynomial: x - 3579113
# Evaluating for 3321456 with 3579113: Decrypted Result = -16103.562900014289, Direct Result = -257657.000000000
# Generated Polynomial: x - 5506064
# Evaluating for 3321456 with 5506064: Decrypted Result = -136538.00480025937, Direct Result = -2184608.00000000
# Generated Polynomial: x - 5561835
# Evaluating for 3321456 with 5561835: Decrypted Result = -140023.69284298437, Direct Result = -2240379.00000000
# Generated Polynomial: x - 6584737
# Evaluating for 3321456 with 6584737: Decrypted Result = -203955.06908735595, Direct Result = -3263281.00000000
# Generated Polynomial: x - 1234
# Evaluating for 3321456 with 1234: Decrypted Result = 207513.88218835706, Direct Result = 3320222.00000000
# Generated Polynomial: x - 8638440
# Evaluating for 8792272 with 8638440: Decrypted Result = 9614.500903666183, Direct Result = 153832.000000000
# Generated Polynomial: x - 3579113
# Evaluating for 8792272 with 3579113: Decrypted Result = 325822.44850981043, Direct Result = 5213159.00000000
# Generated Polynomial: x - 5506064
# Evaluating for 8792272 with 5506064: Decrypted Result = 205388.00688117894, Direct Result = 3286208.00000000
# Generated Polynomial: x - 5561835
# Evaluating for 8792272 with 5561835: Decrypted Result = 201902.31893483098, Direct Result = 3230437.00000000
# Generated Polynomial: x - 6584737
# Evaluating for 8792272 with 6584737: Decrypted Result = 137970.94191079878, Direct Result = 2207535.00000000
# Generated Polynomial: x - 1234
# Evaluating for 8792272 with 1234: Decrypted Result = 549439.8937512689, Direct Result = 8791038.00000000
# Generated Polynomial: x - 8638440
# Evaluating for 4718199 with 8638440: Decrypted Result = -245015.0705252149, Direct Result = -3920241.00000000
# Generated Polynomial: x - 3579113
# Evaluating for 4718199 with 3579113: Decrypted Result = 71192.87742794833, Direct Result = 1139086.00000000
# Generated Polynomial: x - 5506064
# Evaluating for 4718199 with 5506064: Decrypted Result = -49241.56434397035, Direct Result = -787865.000000000
# Generated Polynomial: x - 5561835
# Evaluating for 4718199 with 5561835: Decrypted Result = -52727.251654002466, Direct Result = -843636.000000000
# Generated Polynomial: x - 6584737
# Evaluating for 4718199 with 6584737: Decrypted Result = -116658.62881319682, Direct Result = -1866538.00000000
# Generated Polynomial: x - 1234
# Evaluating for 4718199 with 1234: Decrypted Result = 294810.32243278885, Direct Result = 4716965.00000000
# Generated Polynomial: x - 8638440
# Evaluating for 3119089 with 8638440: Decrypted Result = -344959.4494181733, Direct Result = -5519351.00000000
# Generated Polynomial: x - 3579113
# Evaluating for 3119089 with 3579113: Decrypted Result = -28751.501225231554, Direct Result = -460024.000000000
# Generated Polynomial: x - 5506064
# Evaluating for 3119089 with 5506064: Decrypted Result = -149185.9424161588, Direct Result = -2386975.00000000
# Generated Polynomial: x - 5561835
# Evaluating for 3119089 with 5561835: Decrypted Result = -152671.6307063749, Direct Result = -2442746.00000000
# Generated Polynomial: x - 6584737
# Evaluating for 3119089 with 6584737: Decrypted Result = -216603.0075785762, Direct Result = -3465648.00000000
# Generated Polynomial: x - 1234
# Evaluating for 3119089 with 1234: Decrypted Result = 194865.9442868799, Direct Result = 3117855.00000000
# Generated Polynomial: x - 8638440
# Evaluating for 1234 with 8638440: Decrypted Result = -539825.3937176084, Direct Result = -8637206.00000000
# Generated Polynomial: x - 3579113
# Evaluating for 1234 with 3579113: Decrypted Result = -223617.44514522652, Direct Result = -3577879.00000000
# Generated Polynomial: x - 5506064
# Evaluating for 1234 with 5506064: Decrypted Result = -344051.8868860267, Direct Result = -5504830.00000000
# Generated Polynomial: x - 5561835
# Evaluating for 1234 with 5561835: Decrypted Result = -347537.5743665871, Direct Result = -5560601.00000000
# Generated Polynomial: x - 6584737
# Evaluating for 1234 with 6584737: Decrypted Result = -411468.9516592546, Direct Result = -6583503.00000000
# Generated Polynomial: x - 1234
# Evaluating for 1234 with 1234: Decrypted Result = 1.1700167556908057e-07, Direct Result = 0E-122
# Suspicious people found: [1234]
